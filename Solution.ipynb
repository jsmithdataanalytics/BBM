# %% [markdown]
# # Bought By Many Interview Exercise

# %%
import os
import json
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 1. Process input files into CSVs

# %% [markdown]
# First, let's take a look at some policies to see what we're dealing with.

# %%
with open(f'data/policies/{os.listdir("data/policies")[0]}') as file:
    text = file.read()
    policy = json.loads(text)

print(json.dumps(policy, indent=2))
# Out:
# {
#   "_id": "5d1cd832cd9d4f5ef38efdef",
#   "created_at": 1562171442321,
#   "updated_at": 1578003116164,
#   "account_ref": "BBM",
#   "cessation_date": 1593734400000,
#   "data": {
#     "insured_entities": [
#       {
#         "breed": "CHIHUAHUA",
#         "breed_friendly": "Chihuahua",
#         "dob": 1557273600000,
#         "gender": "MALE",
#         "healthy": true,
#         "microchipped": true,
#         "pedigree": false,
#         "pedigree_type": "CROSS_BREED",
#         "pet_address_postcode": "CV6",
#         "pet_name": "Alfie",
#         "photo": "https://bbm-user-data-prod.s3.amazonaws.com/96993249-9147-47eb-9d80-22c561a1d5fd/pet-photos/a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb/ADB8F502-A44A-414E-98AC-DE6FFB678BCD-3p4dz.jpeg",
#         "ref": "332924",
#         "spayed_neutered": true,
#         "species": "DOG",
#         "uuid": "8aeef6e5-d182-4002-94d9-02f31c357760",
#         "value": 450
#       }
#     ],
#     "payment": {
#       "direct_debit_account_details": "gAAAAABdHNgjMb8lKC5AoOX_wdLt3y1Jj3vRPg5jBKJYQSWvqKVQWnuQI4hZy-0dfqVm-PmmWMnMY26msXg9FOrdQ_wI2V03cw==",
#       "direct_debit_account_name": "<removed>",
#       "method": "IBSUITE_DIRECT_DEBIT"
#     },
#     "policy": {
#       "addons": "",
#       "caseworker": "bbm",
#       "cessation_date": 1593734400000,
#       "fixed_excess": "69",
#       "inception_date": 1562112000000,
#       "invalid_card_details": "EMPTY",
#       "key": "CLASSIC",
#       "option": "Regular",
#       "payment_type": "DIRECT_DEBIT",
#       "variation": 1,
#       "voluntary_excess": "0"
#     },
#     "policy_holders": [
#       {
#         "address": {
#           "city": "Coventry",
#           "country": "United Kingdom",
#           "country_code": "GBR",
#           "county": "West Midlands",
#           "line1": "<removed>",
#           "line2": "<removed>",
#           "postcode": "CV6"
#         },
#         "address_1": "<removed>",
#         "address_2": "<removed>",
#         "address_city": "Coventry",
#         "address_postcode": "CV6",
#         "agree_terms": true,
#         "dob": 1974,
#         "email": "<removed>",
#         "first_name": "<removed>",
#         "full_name": "Emma Fox",
#         "iba_customer_number": "1011260000575132",
#         "last_name": "<removed>",
#         "telephone": "<removed>",
#         "title": "MRS",
#         "uuid": "00753435-74ba-4bff-8d25-9f868131e159"
#       }
#     ],
#     "product_variation": {
#       "coverages": [
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 150
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Farewell Cover",
#               [
#                 "Vet\u2019s costs, cremation and burial when your pet has to be put to sleep - \u00a3150"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "farewell"
#         },
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 2000000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 250
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Liability",
#               [
#                 "Cover for legal action against you or your dog \u2013 \u00a32,000,000 per incident",
#                 "Excess you would pay for each claim - \u00a3250"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "liability"
#         },
#         {
#           "allowances": {
#             "per-year": {
#               "amount": 1000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Emergency Minding",
#               [
#                 "Boarding with a licensed pet minder if you or your family member make an unplanned hospital visit - \u00a31,000 pet year"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "pet-minding"
#         },
#         {
#           "allowances": {
#             "per-year": {
#               "amount": 7000
#             },
#             "per-year-complementary": {
#               "amount": 1000,
#               "help": "The maximum a customer can claim for Complementary treatments. Amount claimed for Complementary also reduce the vet-fees amount."
#             }
#           },
#           "excesses": {
#             "copayment_under_9_percent": {
#               "amount": 0
#             },
#             "mandatory_under_9": {
#               "amount": 69
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Vet fees",
#               [
#                 "Total vet fee cover of up to \u00a37,000 each year.",
#                 "<span id='regular-lifetime-cover'>Lifetime (or \u2018yearly limit\u2019) insurance:  Vet fee cover limit resets after each renewal; good if your pet develops a long term illness. Premiums may increase each year, and when your pet turns 9 a fixed excess of \u00a369 plus 20% of the cost of each vet fee claim will apply.</span>",
#                 "Complementary treatments (e.g. acupuncture) \u2013 \u00a31,000",
#                 "Dental treatments (accident only)"
#               ]
#             ],
#             [
#               "Vet fee excess",
#               [
#                 "An amount you would contribute towards a vet fee claim",
#                 "Pets under 9: Choose between zero excess or \u00a369 plus 20% of each claim",
#                 "Pets 9 and over: There is a fixed excess of \u00a369 plus 20% of each claim"
#               ]
#             ]
#           ],
#           "price": {
#             "annual": {
#               "amount": 17891,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly": {
#               "amount": 1491,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly1": {
#               "amount": 1490,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             }
#           },
#           "relativities": "<removed>",
#           "section": "vet-fees"
#         }
#       ],
#       "headline": "Lifetime cover (yearly limit cover). Zero-excess option and \u00a37,000 vet fee limit each year.",
#       "name": "Regular",
#       "optional_coverages": [],
#       "policy_details_summary": [
#         [
#           "Vet fees",
#           [
#             "\u00a37,000 each year. This is a <a href='#regular-lifetime-cover'>lifetime policy.</a>"
#           ]
#         ],
#         [
#           "Excess",
#           [
#             "Choice of zero excess or \u00a369 plus 20% of each claim (fixed at \u00a369 plus 20% for pets 9 and over)"
#           ]
#         ],
#         [
#           "Liability (dogs only)",
#           [
#             "\u00a32,000,000 per incident"
#           ]
#         ],
#         [
#           "Farewell cover",
#           [
#             "\u00a3150 per pet"
#           ]
#         ],
#         [
#           "Emergency minding",
#           [
#             "\u00a31,000 per year"
#           ]
#         ]
#       ],
#       "price": {
#         "annual": {
#           "amount": 17891,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         },
#         "monthly": {
#           "amount": 1491,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         },
#         "monthly1": {
#           "amount": 1490,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         }
#       },
#       "pricing_key": "CLASSIC",
#       "rules": {
#         "cancellation": {
#           "features": {
#             "pro_rata_cancel_refund": null
#           },
#           "rules": {
#             "notice_autocancel": null
#           }
#         },
#         "product": {
#           "features": {
#             "endorsement_notes": true,
#             "exclusion": false,
#             "flexible_contract_duration": false,
#             "index_sum_assured": null
#           },
#           "rules": {
#             "contract_duration_days_or_months": "12m",
#             "mta_max_future_date_days": 28,
#             "multi_pet_discount": 0.15,
#             "multi_policy_discount": {},
#             "supporting_evidence_required": false
#           }
#         },
#         "rating": {
#           "rules": {
#             "cancellation_fee": 0,
#             "cap_and_collar": false
#           }
#         },
#         "renewals": {
#           "features": {
#             "auto_renew": true
#           },
#           "rules": {
#             "product_discontinued": false
#           }
#         }
#       }
#     },
#     "sales_channel": "web"
#   },
#   "events_timeline": [
#     {
#       "key": "system-policy-onrisk",
#       "created_at": 1562171442445,
#       "eid": "7394e1b1-9e8f-44bb-9216-29040563c498",
#       "type": "system",
#       "category": "policy",
#       "action": "onrisk",
#       "profile_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#       "data": {
#         "cessation_date": 1593734399000,
#         "inception_date": 1562168177000,
#         "premium": 17891,
#         "agency_ref": "BBM",
#         "policy_uuid": "18de854b-6a0b-4c7e-9c96-affc01770b7a",
#         "productline_key": "cat-dog",
#         "user_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#         "quote_uuid": "a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb",
#         "policy_history_uuid": "3d8fa9cf-0c01-49f9-8dc3-986049860097"
#       }
#     },
#     {
#       "key": "system-policy-start",
#       "created_at": 1562174530562,
#       "eid": "1e2490b6-58a8-490a-9c08-4dfa2635947f",
#       "type": "system",
#       "category": "policy",
#       "action": "start",
#       "profile_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#       "data": {
#         "agency_ref": "BBM",
#         "policy_uuid": "18de854b-6a0b-4c7e-9c96-affc01770b7a",
#         "productline_key": "cat-dog",
#         "user_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#         "quote_uuid": "a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb",
#         "policy_history_uuid": "21d44119-717a-4ad1-bc8a-d82c5f719016"
#       }
#     }
#   ],
#   "history": [],
#   "inception_date": 1562112000000,
#   "locked": false,
#   "metadata": {
#     "cancellation_date": null,
#     "contract_end_date": 1593734400000,
#     "contract_number": "1031268000101958-1",
#     "contract_start_date": 1562112000000,
#     "decay_date": 1593734400000,
#     "iba_ref": "1031268000101958",
#     "termination_cause": null,
#     "incepted": true,
#     "policy_original_start_date": 1562112000000
#   },
#   "mta": {},
#   "notes": [],
#   "owner": "96993249-9147-47eb-9d80-22c561a1d5fd",
#   "payments": [
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1490,
#       "account_number_last_4_digits": "0357",
#       "date": 1562112000000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1564790400000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1567468800000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1570060800000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1572739200000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1575331200000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1578009600000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1580688000000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1583193600000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1585872000000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1588464000000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     },
#     {
#       "created_at": 1562171573000,
#       "updated_at": 1562171573000,
#       "amount": 1491,
#       "account_number_last_4_digits": "0357",
#       "date": 1591142400000,
#       "payment_status": "DIRECT_DEBIT_PAYMENT_SCHEDULED"
#     }
#   ],
#   "productline": "1.16",
#   "productline_key": "cat-dog",
#   "products": [
#     {
#       "coverages": [
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 150
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Farewell Cover",
#               [
#                 "Vet\u2019s costs, cremation and burial when your pet has to be put to sleep - \u00a3150"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "farewell"
#         },
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 2000000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 250
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Liability",
#               [
#                 "Cover for legal action against you or your dog \u2013 \u00a32,000,000 per incident",
#                 "Excess you would pay for each claim - \u00a3250"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "liability"
#         },
#         {
#           "allowances": {
#             "per-year": {
#               "amount": 1000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Emergency Minding",
#               [
#                 "Boarding with a licensed pet minder if you or your family member make an unplanned hospital visit - \u00a31,000 pet year"
#               ]
#             ]
#           ],
#           "relativities": "<removed>",
#           "section": "pet-minding"
#         },
#         {
#           "allowances": {
#             "per-year": {
#               "amount": 7000
#             },
#             "per-year-complementary": {
#               "amount": 1000,
#               "help": "The maximum a customer can claim for Complementary treatments. Amount claimed for Complementary also reduce the vet-fees amount."
#             }
#           },
#           "excesses": {
#             "copayment_under_9_percent": {
#               "amount": 0
#             },
#             "mandatory": {
#               "amount": 69
#             },
#             "mandatory_under_9": {
#               "amount": 69
#             }
#           },
#           "optional": false,
#           "policy_details_text": [
#             [
#               "Vet fees",
#               [
#                 "Total vet fee cover of up to \u00a37,000 each year.",
#                 "<span id='regular-lifetime-cover'>Lifetime (or \u2018yearly limit\u2019) insurance:  Vet fee cover limit resets after each renewal; good if your pet develops a long term illness. Premiums may increase each year, and when your pet turns 9 a fixed excess of \u00a369 plus 20% of the cost of each vet fee claim will apply.</span>",
#                 "Complementary treatments (e.g. acupuncture) \u2013 \u00a31,000",
#                 "Dental treatments (accident only)"
#               ]
#             ],
#             [
#               "Vet fee excess",
#               [
#                 "An amount you would contribute towards a vet fee claim",
#                 "Pets under 9: Choose between zero excess or \u00a369 plus 20% of each claim",
#                 "Pets 9 and over: There is a fixed excess of \u00a369 plus 20% of each claim"
#               ]
#             ]
#           ],
#           "price": {
#             "annual": {
#               "amount": 17891,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly": {
#               "amount": 1491,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly1": {
#               "amount": 1490,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             }
#           },
#           "relativities": "<removed>",
#           "section": "vet-fees"
#         }
#       ],
#       "headline": "Lifetime cover (yearly limit cover). Zero-excess option and \u00a37,000 vet fee limit each year.",
#       "name": "Regular",
#       "optional_coverages": [
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 1000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": true,
#           "policy_details_text": [
#             [
#               "Passing away cover",
#               [
#                 "Cover for the original or market value of your pet - up to \u00a31,000",
#                 "For pets 9 and over, we do not cover passing away due to illness"
#               ]
#             ]
#           ],
#           "price": {
#             "annual": {
#               "amount": 447,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly": {
#               "amount": 38,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly1": {
#               "amount": 29,
#               "discount_amount": -1,
#               "discount_percentage": -4
#             }
#           },
#           "relativities": "<removed>",
#           "section": "death"
#         },
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 1000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": true,
#           "policy_details_text": [
#             [
#               "Lost or stolen cover",
#               [
#                 "Advertising costs, reward and the original or market value of your pet \u2013 up to \u00a31,000 in total"
#               ]
#             ]
#           ],
#           "price": {
#             "annual": {
#               "amount": 447,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly": {
#               "amount": 38,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly1": {
#               "amount": 29,
#               "discount_amount": -1,
#               "discount_percentage": -4
#             }
#           },
#           "relativities": "<removed>",
#           "section": "theft-loss"
#         },
#         {
#           "allowances": {
#             "per-incident": {
#               "amount": 1000
#             }
#           },
#           "excesses": {
#             "mandatory": {
#               "amount": 0
#             }
#           },
#           "optional": true,
#           "policy_details_text": [
#             [
#               "Travel cover",
#               [
#                 "Policy vet fee limit extends within the EU, plus \u00a31,000 for many other specified costs, such as delays and cancellation due to your pet"
#               ]
#             ]
#           ],
#           "price": {
#             "annual": {
#               "amount": 268,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly": {
#               "amount": 22,
#               "discount_amount": 0,
#               "discount_percentage": 0
#             },
#             "monthly1": {
#               "amount": 26,
#               "discount_amount": -5,
#               "discount_percentage": -24
#             }
#           },
#           "relativities": "<removed>",
#           "section": "travel"
#         }
#       ],
#       "policy_details_summary": [
#         [
#           "Vet fees",
#           [
#             "\u00a37,000 each year. This is a <a href='#regular-lifetime-cover'>lifetime policy.</a>"
#           ]
#         ],
#         [
#           "Excess",
#           [
#             "Choice of zero excess or \u00a369 plus 20% of each claim (fixed at \u00a369 plus 20% for pets 9 and over)"
#           ]
#         ],
#         [
#           "Liability (dogs only)",
#           [
#             "\u00a32,000,000 per incident"
#           ]
#         ],
#         [
#           "Farewell cover",
#           [
#             "\u00a3150 per pet"
#           ]
#         ],
#         [
#           "Emergency minding",
#           [
#             "\u00a31,000 per year"
#           ]
#         ]
#       ],
#       "price": {
#         "annual": {
#           "amount": 17891,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         },
#         "monthly": {
#           "amount": 1491,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         },
#         "monthly1": {
#           "amount": 1490,
#           "discount_amount": 0,
#           "discount_percentage": 0
#         }
#       },
#       "pricing_key": "CLASSIC",
#       "rules": {
#         "cancellation": {
#           "features": {
#             "pro_rata_cancel_refund": null
#           },
#           "rules": {
#             "notice_autocancel": null
#           }
#         },
#         "product": {
#           "features": {
#             "endorsement_notes": true,
#             "exclusion": false,
#             "flexible_contract_duration": false,
#             "index_sum_assured": null
#           },
#           "rules": {
#             "contract_duration_days_or_months": "12m",
#             "mta_max_future_date_days": 28,
#             "multi_pet_discount": 0.15,
#             "multi_policy_discount": {},
#             "supporting_evidence_required": false
#           }
#         },
#         "rating": {
#           "rules": {
#             "cancellation_fee": 0,
#             "cap_and_collar": false
#           }
#         },
#         "renewals": {
#           "features": {
#             "auto_renew": true
#           },
#           "rules": {
#             "product_discontinued": false
#           }
#         }
#       }
#     }
#   ],
#   "quote_uuid": "a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb",
#   "ref": "1031268000101958",
#   "renewal_count": 0,
#   "schema": "1.0",
#   "status": "ON_RISK",
#   "timeline": [
#     {
#       "created_at": 1562171442511,
#       "updated_at": 1562171442511,
#       "data": {
#         "cessation_date": 1593734399000,
#         "inception_date": 1562168177000,
#         "premium": 17891,
#         "agency_ref": "BBM",
#         "policy_uuid": "18de854b-6a0b-4c7e-9c96-affc01770b7a",
#         "productline_key": "cat-dog",
#         "user_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#         "quote_uuid": "a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb",
#         "policy_history_uuid": "3d8fa9cf-0c01-49f9-8dc3-986049860097"
#       },
#       "event_key": "system-policy-onrisk"
#     },
#     {
#       "created_at": 1562174530685,
#       "updated_at": 1562174530685,
#       "data": {
#         "agency_ref": "BBM",
#         "policy_uuid": "18de854b-6a0b-4c7e-9c96-affc01770b7a",
#         "productline_key": "cat-dog",
#         "user_uuid": "96993249-9147-47eb-9d80-22c561a1d5fd",
#         "quote_uuid": "a17ef4c4-839e-46ba-9b0d-67fb1c7d89fb",
#         "policy_history_uuid": "21d44119-717a-4ad1-bc8a-d82c5f719016"
#       },
#       "event_key": "system-policy-start"
#     }
#   ],
#   "uuid": "18de854b-6a0b-4c7e-9c96-affc01770b7a",
#   "refreshed_at": 1572347100109,
#   "document_uri": "96993249-9147-47eb-9d80-22c561a1d5fd/policies/18de854b-6a0b-4c7e-9c96-affc01770b7a/document-1565949281.pdf"
# }

# %% [markdown]
# We see a lot of information, including details of:
#
# * the policy holder
# * the insured pets
# * the insurance products included in the policy (allowances, pricing, rules etc.)
# * payments
# * event timelines (on risk, started, cancelled etc.)
